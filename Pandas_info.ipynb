# %%
import pandas as pd

# %%
data = {
    'Emp_ID': [101, 102, 103, 104, 105, 106],
    'Name': ['Aarav', 'Isha', 'Rahul', 'Sneha', 'Kiran', 'Fatima'],
    'Department': ['HR', 'IT', 'IT', 'Finance', 'HR', 'Finance'],
    'Salary': [50000, 65000, 60000, 'np.nan', 52000, 58000],
    'Experience': [2, 5, 3, 7, 4, 'np.nan'],
    'City': ['Delhi', 'Mumbai', 'Pune', 'Delhi', 'Chennai', 'Pune']
}

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#    Emp_ID    Name Department  Salary Experience     City
# 0     101   Aarav         HR   50000          2    Delhi
# 1     102    Isha         IT   65000          5   Mumbai
# 2     103   Rahul         IT   60000          3     Pune
# 3     104   Sneha    Finance  np.nan          7    Delhi
# 4     105   Kiran         HR   52000          4  Chennai
# 5     106  Fatima    Finance   58000     np.nan     Pune

# %%
df.head()
# Out:
#    Emp_ID   Name Department  Salary Experience     City
# 0     101  Aarav         HR   50000          2    Delhi
# 1     102   Isha         IT   65000          5   Mumbai
# 2     103  Rahul         IT   60000          3     Pune
# 3     104  Sneha    Finance  np.nan          7    Delhi
# 4     105  Kiran         HR   52000          4  Chennai

# %%
df.tail()
# Out:
#    Emp_ID    Name Department  Salary Experience     City
# 1     102    Isha         IT   65000          5   Mumbai
# 2     103   Rahul         IT   60000          3     Pune
# 3     104   Sneha    Finance  np.nan          7    Delhi
# 4     105   Kiran         HR   52000          4  Chennai
# 5     106  Fatima    Finance   58000     np.nan     Pune

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Emp_ID      6 non-null      int64
#  1   Name        6 non-null      object
#  2   Department  6 non-null      object
#  3   Salary      6 non-null      object
#  4   Experience  6 non-null      object
#  5   City        6 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 420.0+ bytes

# %%
df.describe()
# Out:
#            Emp_ID
# count    6.000000
# mean   103.500000
# std      1.870829
# min    101.000000
# 25%    102.250000
# 50%    103.500000
# 75%    104.750000
# max    106.000000

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df.shape
# Out:
# (6, 6)

# %%
df.columns
# Out:
# Index(['Emp_ID', 'Name', 'Department', 'Salary', 'Experience', 'City'], dtype='object')

# %%
df.isnull().sum()
# Out:
# Emp_ID        0
# Name          0
# Department    0
# Salary        0
# Experience    0
# City          0
# dtype: int64

# %%
df['Salary'] = pd.to_numeric(df['Salary'], errors='coerce')

df['Salary'].fillna(df['Salary'].mean(), inplace=True)

print(df)
# Out:
#    Emp_ID    Name Department   Salary Experience     City
# 0     101   Aarav         HR  50000.0          2    Delhi
# 1     102    Isha         IT  65000.0          5   Mumbai
# 2     103   Rahul         IT  60000.0          3     Pune
# 3     104   Sneha    Finance  57000.0          7    Delhi
# 4     105   Kiran         HR  52000.0          4  Chennai
# 5     106  Fatima    Finance  58000.0     np.nan     Pune
# /tmp/ipython-input-4187920633.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
# ...

# %%
df['Bonus'] = df['Salary'] * 0.1

# %%
df
# Out:
#    Emp_ID    Name Department   Salary Experience     City   Bonus
# 0     101   Aarav         HR  50000.0          2    Delhi  5000.0
# 1     102    Isha         IT  65000.0          5   Mumbai  6500.0
# 2     103   Rahul         IT  60000.0          3     Pune  6000.0
# 3     104   Sneha    Finance  57000.0          7    Delhi  5700.0
# 4     105   Kiran         HR  52000.0          4  Chennai  5200.0
# 5     106  Fatima    Finance  58000.0     np.nan     Pune  5800.0

# %%
df.drop('City', axis=1, inplace=True)
df
# Out:
#    Emp_ID    Name Department   Salary Experience   Bonus
# 0     101   Aarav         HR  50000.0          2  5000.0
# 1     102    Isha         IT  65000.0          5  6500.0
# 2     103   Rahul         IT  60000.0          3  6000.0
# 3     104   Sneha    Finance  57000.0          7  5700.0
# 4     105   Kiran         HR  52000.0          4  5200.0
# 5     106  Fatima    Finance  58000.0     np.nan  5800.0

# %%
df.sort_values(by='Salary', ascending=True)
# Out:
#    Emp_ID    Name Department   Salary Experience   Bonus
# 0     101   Aarav         HR  50000.0          2  5000.0
# 4     105   Kiran         HR  52000.0          4  5200.0
# 3     104   Sneha    Finance  57000.0          7  5700.0
# 5     106  Fatima    Finance  58000.0     np.nan  5800.0
# 2     103   Rahul         IT  60000.0          3  6000.0
# 1     102    Isha         IT  65000.0          5  6500.0

# %%
df.groupby('Department')['Salary'].mean()
# Out:
# Department
# Finance    57500.0
# HR         51000.0
# IT         62500.0
# Name: Salary, dtype: float64

# %%
dept_data = {
    'Department': ['HR', 'IT', 'Finance'],
    'Manager': ['Ravi', 'Anita', 'Suresh']
}
dept_df = pd.DataFrame(df)

merged = pd.merge(df, dept_df, on='Department', how='left')   # Merge
concat_df = pd.concat([df, df], axis=0)                      # Concatenate vertically

# %%
concat_df
# Out:
#    Emp_ID    Name Department   Salary Experience   Bonus
# 0     101   Aarav         HR  50000.0          2  5000.0
# 1     102    Isha         IT  65000.0          5  6500.0
# 2     103   Rahul         IT  60000.0          3  6000.0
# 3     104   Sneha    Finance  57000.0          7  5700.0
# 4     105   Kiran         HR  52000.0          4  5200.0
# 5     106  Fatima    Finance  58000.0     np.nan  5800.0
# 0     101   Aarav         HR  50000.0          2  5000.0
# 1     102    Isha         IT  65000.0          5  6500.0
# 2     103   Rahul         IT  60000.0          3  6000.0
# 3     104   Sneha    Finance  57000.0          7  5700.0
# 4     105   Kiran         HR  52000.0          4  5200.0
# 5     106  Fatima    Finance  58000.0     np.nan  5800.0

# %%
df['Tax'] = df['Salary'].apply(lambda x: x * 0.05)

# %%
df
# Out:
#    Emp_ID    Name Department   Salary Experience   Bonus     Tax
# 0     101   Aarav         HR  50000.0          2  5000.0  2500.0
# 1     102    Isha         IT  65000.0          5  6500.0  3250.0
# 2     103   Rahul         IT  60000.0          3  6000.0  3000.0
# 3     104   Sneha    Finance  57000.0          7  5700.0  2850.0
# 4     105   Kiran         HR  52000.0          4  5200.0  2600.0
# 5     106  Fatima    Finance  58000.0     np.nan  5800.0  2900.0
